# %% [markdown]
# We went through basic in python
#
# So lets define some variables

# %%
### Simple Variables
x = 5
y = 7

### Variables as specific values

# %% [markdown]
# Variables can be used to assign other variables, but this isnt like assigning a dynamic equation to the variables

# %%
#### Trying to enter an equation into a variabl
Eqn = (x*y)
print(Eqn)


#### Lets try changing the values for the variables in the equation
y=
print(Eqn)

#### Lets see how we can update the equation

print(Eqn)

# %% [markdown]
# Function's
#
# Just like variables, we can also define equations, but to do this we need to use functions. A function allows for easing up our coding processes. While python has its own functions, we can define new functions
#
# Pre defined functions:
#
# `print()
# len()
# int()`
#
# To define function of your own:
#
# `def function_name(var1,var2...):
#     var_ans = Equation
#     return var_ans`
#
# Try Defining these equations as functions:
#
# ![image.png](attachment:228baf5b-4eb8-4a6f-b5fd-ee48e56fae14.png)

# %%
### Forward Difference (Example )
def forward_dif(f, x, dx):
    df = ( f(x+dx)-f(x) ) / dx
    return df

### Backward Difference


### Central Difference

# %% [markdown]
# So why do we use functions? Lets test them out below:
# Lets define a function, and use it with our earlier functions.
# We use our new defined functions to find our values

# %%
### Set up an equation, we know we cant use a variable, so we will create an equation


### Use the defined equation with our various difference functions
